# %%
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt

# %%
# Load in the dataframe
df = open('C:\\Users\\admin\\Downloads\\AGGREGATE.txt','r').read()
x, y = np.ogrid[:500, :500]
wc = WordCloud(background_color="white") 
wc.generate(df)

plt.axis("on")
plt.imshow(wc)#, creating a worldcloud on the same panel for "abs1.txt")
plt.show()
